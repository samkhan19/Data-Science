# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("CardioGoodFitness-1.csv")         #use tab to type csv file

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %%
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
df.tail(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 170   TM798   31    Male         16     Partnered      6        5   89641
# 171   TM798   33  Female         18     Partnered      4        5   95866
# 172   TM798   34    Male         16        Single      5        5   92131
# 173   TM798   35    Male         16     Partnered      4        5   92131
# 174   TM798   38    Male         18     Partnered      5        5  104581
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 170    260
# 171    200
# 172    150
# 173    360
# 174    150
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
df.sample()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 120   TM498   33   Male         13     Partnered      4        4   53439
#
#      Miles
# 120    170

# %%
df.sample(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 25    TM195   24    Male         13     Partnered      3        2   42069
# 110   TM498   26    Male         16        Single      4        3   51165
# 28    TM195   25    Male         14     Partnered      2        3   45480
# 48    TM195   28    Male         14        Single      4        3   54576
# 95    TM498   24    Male         14        Single      3        4   48891
# 134   TM498   38    Male         16     Partnered      3        3   59124
# 174   TM798   38    Male         18     Partnered      5        5  104581
# 115   TM498   31    Male         16     Partnered      3        3   52302
# 5     TM195   20  Female         14     Partnered      3        3   32973
# 59    TM195   33  Female         16        Single      2        2   55713
#
#      Miles
# 25      47
# 110    106
# 28      56
# 48     113
# 95     106
# 134    106
# 174    150
# 115     95
# 5       66
# 59      38

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.shape
# Out:
# (180, 9)

# %%
df.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# ### Example:2

# %%
df1 = pd.read_csv("hotel_bookings.csv")

# %%
df1.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df1.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
df1.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df1.tail(10)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119380             August                        35
# 119381             August                        35
# 119382             August                        35
# 119383             August                        35
# ...

# %%
df1.sample()
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 79952  City Hotel            0         21               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 79952           November                        45                          5
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 79952                        0                     3       2  ...
#
#        deposit_type  agent company days_in_waiting_list customer_type    adr  \
# 79952    No Deposit   16.0     NaN                    0     Transient  37.07
#
#        required_car_parking_spaces  total_of_special_requests  \
# 79952                            0                          1
#
#        reservation_status reservation_status_date
# 79952           Check-Out              11-08-2015
#
# [1 rows x 32 columns]

# %%
df1.sample(5)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 111289    City Hotel            0        117               2017
# 7385    Resort Hotel            1        168               2016
# 74246     City Hotel            1        377               2015
# 56490     City Hotel            1        258               2016
# 10771   Resort Hotel            1         10               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 111289                May                        19
# 7385               August                        32
# 74246             October                        44
# 56490           September                        37
# 10771               April                        14
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 111289                          8                        1
# 7385                            6                        2
# 74246                          29                        0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df1.shape
# Out:
# (119390, 32)

# %%
df1.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df1.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df1.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df1.describe(include="all")
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# ## -----------------------------------------------------------------------------------------------------------------------------

# %%
import numpy as np
import pandas as pd

# %%
labels=['w','x','y','z']
sample_list=[100,200,300,400]
array=np.array([1,2,3,4])
dict={'w':10,'x':20,'y':30,'z':40}

# %% [markdown]
# ### pd.series --> Unidimensional
# ### pd.dataframe --> twodimensional

# %%
pd.Series(data=array)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int32

# %%
pd.Series(data=sample_list,index=labels)
# Out:
# w    100
# x    200
# y    300
# z    400
# dtype: int64

# %%
pd.Series(sample_list,array)
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# dtype: int64

# %%
pd.Series(dict)
# Out:
# w    10
# x    20
# y    30
# z    40
# dtype: int64

# %%
sport1=pd.Series([1,2,3,4],index=['cricket','golf','fball','bsktball'])

# %%
sport1['cricket']
# Out:
# 1

# %%
sport2=pd.Series([11,2,3,4],index=['cricket','golf','fball','bsktball'])

# %%
sport2['cricket']
# Out:
# 11

# %%
sport1+sport2
# Out:
# cricket     12
# golf         4
# fball        6
# bsktball     8
# dtype: int64

# %%
df1=pd.DataFrame(np.random.rand(8,5),index='A B C D E F G H'.split(),columns='Score1 Score2 Score3 Score4 Score5'.split())
df1
# Out:
#      Score1    Score2    Score3    Score4    Score5
# A  0.445772  0.079376  0.699584  0.119140  0.613218
# B  0.936736  0.566278  0.636427  0.584174  0.286025
# C  0.471616  0.157135  0.418699  0.024094  0.905900
# D  0.048975  0.100303  0.850864  0.969902  0.669735
# E  0.871083  0.684644  0.949251  0.238364  0.772436
# F  0.535991  0.644510  0.385225  0.379472  0.043306
# G  0.670813  0.038825  0.662794  0.277187  0.558658
# H  0.280199  0.584925  0.980612  0.720557  0.828916

# %%
df1['Score3']
# Out:
# A    0.699584
# B    0.636427
# C    0.418699
# D    0.850864
# E    0.949251
# F    0.385225
# G    0.662794
# H    0.980612
# Name: Score3, dtype: float64

# %%
df1[['Score2','Score1','Score5']]
# Out:
#      Score2    Score1    Score5
# A  0.079376  0.445772  0.613218
# B  0.566278  0.936736  0.286025
# C  0.157135  0.471616  0.905900
# D  0.100303  0.048975  0.669735
# E  0.684644  0.871083  0.772436
# F  0.644510  0.535991  0.043306
# G  0.038825  0.670813  0.558658
# H  0.584925  0.280199  0.828916

# %%
df1['Score6']=df1['Score1']+df1['Score2']
df1
# Out:
#      Score1    Score2    Score3    Score4    Score5    Score6
# A  0.445772  0.079376  0.699584  0.119140  0.613218  0.525148
# B  0.936736  0.566278  0.636427  0.584174  0.286025  1.503014
# C  0.471616  0.157135  0.418699  0.024094  0.905900  0.628751
# D  0.048975  0.100303  0.850864  0.969902  0.669735  0.149278
# E  0.871083  0.684644  0.949251  0.238364  0.772436  1.555727
# F  0.535991  0.644510  0.385225  0.379472  0.043306  1.180501
# G  0.670813  0.038825  0.662794  0.277187  0.558658  0.709638
# H  0.280199  0.584925  0.980612  0.720557  0.828916  0.865124

# %%
df1.drop('Score5',axis=1)
# Out:
#      Score1    Score2    Score3    Score4    Score6
# A  0.445772  0.079376  0.699584  0.119140  0.525148
# B  0.936736  0.566278  0.636427  0.584174  1.503014
# C  0.471616  0.157135  0.418699  0.024094  0.628751
# D  0.048975  0.100303  0.850864  0.969902  0.149278
# E  0.871083  0.684644  0.949251  0.238364  1.555727
# F  0.535991  0.644510  0.385225  0.379472  1.180501
# G  0.670813  0.038825  0.662794  0.277187  0.709638
# H  0.280199  0.584925  0.980612  0.720557  0.865124

# %%
df1.drop("E")
# Out:
#      Score1    Score2    Score3    Score4    Score5    Score6
# A  0.445772  0.079376  0.699584  0.119140  0.613218  0.525148
# B  0.936736  0.566278  0.636427  0.584174  0.286025  1.503014
# C  0.471616  0.157135  0.418699  0.024094  0.905900  0.628751
# D  0.048975  0.100303  0.850864  0.969902  0.669735  0.149278
# F  0.535991  0.644510  0.385225  0.379472  0.043306  1.180501
# G  0.670813  0.038825  0.662794  0.277187  0.558658  0.709638
# H  0.280199  0.584925  0.980612  0.720557  0.828916  0.865124

# %%
df2={'ID':[101,102,103,107,176],'Name':['John','Mercy','Akash','Kavin','Lally'],'Profit':[20,54,56,87,123]}
df=pd.DataFrame(df2)
df
# Out:
#     ID   Name  Profit
# 0  101   John      20
# 1  102  Mercy      54
# 2  103  Akash      56
# 3  107  Kavin      87
# 4  176  Lally     123

# %%
df.drop('ID',axis=1)
# Out:
#     Name  Profit
# 0   John      20
# 1  Mercy      54
# 2  Akash      56
# 3  Kavin      87
# 4  Lally     123

# %%
df.drop('ID',axis=1)
# Out:
#     Name  Profit
# 0   John      20
# 1  Mercy      54
# 2  Akash      56
# 3  Kavin      87
# 4  Lally     123

# %%
df.drop(3)
# Out:
#     ID   Name  Profit
# 0  101   John      20
# 1  102  Mercy      54
# 2  103  Akash      56
# 4  176  Lally     123

# %%
df['Name']
# Out:
# 0     John
# 1    Mercy
# 2    Akash
# 3    Kavin
# 4    Lally
# Name: Name, dtype: object

# %%
df[['Name','ID']]
# Out:
#     Name   ID
# 0   John  101
# 1  Mercy  102
# 2  Akash  103
# 3  Kavin  107
# 4  Lally  176
